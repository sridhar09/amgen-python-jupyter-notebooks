# %% [markdown]
# # Lab: Postb.in
#
# - Use the Postb.in Web UI to create a postbin
# - Perform the following requests to the Postb.in:
#     - GET (with no arguments)
#     - GET (with a query string `?q=foo`)
#     - POST with a JSON body
#     - PUT with a JSON body
#     - DELETE

# %%
import requests

url = 'https://postb.in/1604008826680-2536323263775'
resp = requests.get(url + '/a/b/c/d')
resp

# %%
requests.get(url + '?' + 'a=b&c=d')

# %%
requests.get(url, params={'a': 'Things like this & this are hard, eh?', 'c': 'd'})

# %%
requests.post(url, json={'foo': 'bar'})

# %%
requests.put(url, json={'type': 'put'})

# %%
requests.delete(url, json={'deletes_with': 'a body'})

# %%
requests.get('https://postb.in/api/bin/1604008826680-2536323263775/req/shift').json()

# %% [markdown]
# # Lab: uri templates and Github personal access tokens
#
# - Use https://github.com/settings/tokens to obtain a personal access token
# - Set the authorization header to use your token:
#     ```
#     session = requests.Session()
#     session.headers['Authorization'] = 'token YOUR_TOKEN_HERE'
#     ```
# - Install `uritemplate` and use `uritemplate.expand` to retrieve commit 3a0b9b6617dbad6ed79e01d04312840232943967 from repository `Arborian/recommender.git`

# %%
import requests, uritemplate
session = requests.Session()
session.headers['Authorization'] = 'token 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'
r = session.get('https://api.github.com')

# %%
r.json()['organization_repositories_url']
# Out:
# 'https://api.github.com/orgs/{org}/repos{?type,page,per_page,sort}'

# %%
url = uritemplate.expand(
    r.json()['organization_repositories_url'],
    org='Arborian'
)

# %%
url
# Out:
# 'https://api.github.com/orgs/Arborian/repos'

# %%
r = session.get(url)
repos = r.json()
repos
# Out:
# [{'id': 59764123,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk1OTc2NDEyMw==',
#   'name': 'barin',
#   'full_name': 'Arborian/barin',
#   'private': False,
#   'owner': {'login': 'Arborian',
#    'id': 24494919,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI0NDk0OTE5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24494919?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Arborian',
#    'html_url': 'https://github.com/Arborian',
#    'followers_url': 'https://api.github.com/users/Arborian/followers',
#    'following_url': 'https://api.github.com/users/Arborian/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Arborian/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Arborian/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Arborian/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Arborian/orgs',
#    'repos_url': 'https://api.github.com/users/Arborian/repos',
#    'events_url': 'https://api.github.com/users/Arborian/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Arborian/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/Arborian/barin',
#   'description': 'Yet another MongoDB schema layer',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Arborian/barin',
#   'forks_url': 'https://api.github.com/repos/Arborian/barin/forks',
#   'keys_url': 'https://api.github.com/repos/Arborian/barin/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Arborian/barin/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Arborian/barin/teams',
#   'hooks_url': 'https://api.github.com/repos/Arborian/barin/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Arborian/barin/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Arborian/barin/events',
#   'assignees_url': 'https://api.github.com/repos/Arborian/barin/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Arborian/barin/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Arborian/barin/tags',
#   'blobs_url': 'https://api.github.com/repos/Arborian/barin/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Arborian/barin/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Arborian/barin/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Arborian/barin/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Arborian/barin/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Arborian/barin/languages',
#   'stargazers_url': 'https://api.github.com/repos/Arborian/barin/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Arborian/barin/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Arborian/barin/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Arborian/barin/subscription',
#   'commits_url': 'https://api.github.com/repos/Arborian/barin/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Arborian/barin/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Arborian/barin/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Arborian/barin/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Arborian/barin/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Arborian/barin/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Arborian/barin/merges',
#   'archive_url': 'https://api.github.com/repos/Arborian/barin/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Arborian/barin/downloads',
#   'issues_url': 'https://api.github.com/repos/Arborian/barin/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Arborian/barin/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Arborian/barin/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Arborian/barin/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Arborian/barin/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Arborian/barin/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Arborian/barin/deployments',
#   'created_at': '2016-05-26T16:01:08Z',
#   'updated_at': '2021-07-09T15:27:52Z',
#   'pushed_at': '2021-07-09T15:27:49Z',
#   'git_url': 'git://github.com/Arborian/barin.git',
#   'ssh_url': 'git@github.com:Arborian/barin.git',
#   'clone_url': 'https://github.com/Arborian/barin.git',
#   'svn_url': 'https://github.com/Arborian/barin',
#   'homepage': None,
#   'size': 97,
#   'stargazers_count': 3,
#   'watchers_count': 3,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 1,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 1,
#   'watchers': 3,
#   'default_branch': 'master',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 100812819,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMDA4MTI4MTk=',
#   'name': 'f2e',
#   'full_name': 'Arborian/f2e',
#   'private': False,
#   'owner': {'login': 'Arborian',
#    'id': 24494919,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI0NDk0OTE5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24494919?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Arborian',
#    'html_url': 'https://github.com/Arborian',
#    'followers_url': 'https://api.github.com/users/Arborian/followers',
#    'following_url': 'https://api.github.com/users/Arborian/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Arborian/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Arborian/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Arborian/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Arborian/orgs',
#    'repos_url': 'https://api.github.com/users/Arborian/repos',
#    'events_url': 'https://api.github.com/users/Arborian/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Arborian/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/Arborian/f2e',
#   'description': 'Fax to email gateway',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Arborian/f2e',
#   'forks_url': 'https://api.github.com/repos/Arborian/f2e/forks',
#   'keys_url': 'https://api.github.com/repos/Arborian/f2e/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Arborian/f2e/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Arborian/f2e/teams',
#   'hooks_url': 'https://api.github.com/repos/Arborian/f2e/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Arborian/f2e/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Arborian/f2e/events',
#   'assignees_url': 'https://api.github.com/repos/Arborian/f2e/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Arborian/f2e/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Arborian/f2e/tags',
#   'blobs_url': 'https://api.github.com/repos/Arborian/f2e/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Arborian/f2e/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Arborian/f2e/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Arborian/f2e/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Arborian/f2e/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Arborian/f2e/languages',
#   'stargazers_url': 'https://api.github.com/repos/Arborian/f2e/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Arborian/f2e/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Arborian/f2e/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Arborian/f2e/subscription',
#   'commits_url': 'https://api.github.com/repos/Arborian/f2e/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Arborian/f2e/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Arborian/f2e/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Arborian/f2e/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Arborian/f2e/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Arborian/f2e/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Arborian/f2e/merges',
#   'archive_url': 'https://api.github.com/repos/Arborian/f2e/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Arborian/f2e/downloads',
#   'issues_url': 'https://api.github.com/repos/Arborian/f2e/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Arborian/f2e/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Arborian/f2e/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Arborian/f2e/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Arborian/f2e/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Arborian/f2e/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Arborian/f2e/deployments',
#   'created_at': '2017-08-19T18:11:02Z',
#   'updated_at': '2017-08-20T20:03:33Z',
#   'pushed_at': '2021-06-01T22:00:41Z',
#   'git_url': 'git://github.com/Arborian/f2e.git',
#   'ssh_url': 'git@github.com:Arborian/f2e.git',
#   'clone_url': 'https://github.com/Arborian/f2e.git',
#   'svn_url': 'https://github.com/Arborian/f2e',
#   'homepage': None,
#   'size': 2401,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 1,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 4,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1,
#   'open_issues': 4,
#   'watchers': 0,
#   'default_branch': 'master',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 106596632,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMDY1OTY2MzI=',
#   'name': 'ansible-class',
#   'full_name': 'Arborian/ansible-class',
#   'private': False,
#   'owner': {'login': 'Arborian',
#    'id': 24494919,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI0NDk0OTE5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24494919?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Arborian',
#    'html_url': 'https://github.com/Arborian',
#    'followers_url': 'https://api.github.com/users/Arborian/followers',
#    'following_url': 'https://api.github.com/users/Arborian/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Arborian/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Arborian/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Arborian/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Arborian/orgs',
#    'repos_url': 'https://api.github.com/users/Arborian/repos',
#    'events_url': 'https://api.github.com/users/Arborian/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Arborian/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/Arborian/ansible-class',
#   'description': 'Class repository for Ansible',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Arborian/ansible-class',
#   'forks_url': 'https://api.github.com/repos/Arborian/ansible-class/forks',
#   'keys_url': 'https://api.github.com/repos/Arborian/ansible-class/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Arborian/ansible-class/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Arborian/ansible-class/teams',
#   'hooks_url': 'https://api.github.com/repos/Arborian/ansible-class/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Arborian/ansible-class/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Arborian/ansible-class/events',
#   'assignees_url': 'https://api.github.com/repos/Arborian/ansible-class/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Arborian/ansible-class/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Arborian/ansible-class/tags',
#   'blobs_url': 'https://api.github.com/repos/Arborian/ansible-class/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Arborian/ansible-class/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Arborian/ansible-class/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Arborian/ansible-class/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Arborian/ansible-class/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Arborian/ansible-class/languages',
#   'stargazers_url': 'https://api.github.com/repos/Arborian/ansible-class/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Arborian/ansible-class/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Arborian/ansible-class/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Arborian/ansible-class/subscription',
#   'commits_url': 'https://api.github.com/repos/Arborian/ansible-class/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Arborian/ansible-class/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Arborian/ansible-class/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Arborian/ansible-class/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Arborian/ansible-class/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Arborian/ansible-class/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Arborian/ansible-class/merges',
#   'archive_url': 'https://api.github.com/repos/Arborian/ansible-class/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Arborian/ansible-class/downloads',
#   'issues_url': 'https://api.github.com/repos/Arborian/ansible-class/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Arborian/ansible-class/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Arborian/ansible-class/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Arborian/ansible-class/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Arborian/ansible-class/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Arborian/ansible-class/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Arborian/ansible-class/deployments',
#   'created_at': '2017-10-11T18:58:24Z',
#   'updated_at': '2020-10-08T14:25:20Z',
#   'pushed_at': '2020-10-09T22:19:37Z',
#   'git_url': 'git://github.com/Arborian/ansible-class.git',
#   'ssh_url': 'git@github.com:Arborian/ansible-class.git',
#   'clone_url': 'https://github.com/Arborian/ansible-class.git',
#   'svn_url': 'https://github.com/Arborian/ansible-class',
#   'homepage': None,
#   'size': 4205,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'HTML',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 1,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 112127143,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMTIxMjcxNDM=',
#   'name': 'client-py',
#   'full_name': 'Arborian/client-py',
#   'private': False,
#   'owner': {'login': 'Arborian',
#    'id': 24494919,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI0NDk0OTE5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24494919?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Arborian',
#    'html_url': 'https://github.com/Arborian',
#    'followers_url': 'https://api.github.com/users/Arborian/followers',
#    'following_url': 'https://api.github.com/users/Arborian/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Arborian/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Arborian/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Arborian/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Arborian/orgs',
#    'repos_url': 'https://api.github.com/users/Arborian/repos',
#    'events_url': 'https://api.github.com/users/Arborian/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Arborian/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/Arborian/client-py',
#   'description': 'Python SMART on FHIR client',
#   'fork': True,
#   'url': 'https://api.github.com/repos/Arborian/client-py',
#   'forks_url': 'https://api.github.com/repos/Arborian/client-py/forks',
#   'keys_url': 'https://api.github.com/repos/Arborian/client-py/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Arborian/client-py/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Arborian/client-py/teams',
#   'hooks_url': 'https://api.github.com/repos/Arborian/client-py/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Arborian/client-py/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Arborian/client-py/events',
#   'assignees_url': 'https://api.github.com/repos/Arborian/client-py/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Arborian/client-py/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Arborian/client-py/tags',
#   'blobs_url': 'https://api.github.com/repos/Arborian/client-py/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Arborian/client-py/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Arborian/client-py/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Arborian/client-py/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Arborian/client-py/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Arborian/client-py/languages',
#   'stargazers_url': 'https://api.github.com/repos/Arborian/client-py/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Arborian/client-py/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Arborian/client-py/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Arborian/client-py/subscription',
#   'commits_url': 'https://api.github.com/repos/Arborian/client-py/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Arborian/client-py/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Arborian/client-py/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Arborian/client-py/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Arborian/client-py/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Arborian/client-py/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Arborian/client-py/merges',
#   'archive_url': 'https://api.github.com/repos/Arborian/client-py/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Arborian/client-py/downloads',
#   'issues_url': 'https://api.github.com/repos/Arborian/client-py/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Arborian/client-py/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Arborian/client-py/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Arborian/client-py/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Arborian/client-py/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Arborian/client-py/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Arborian/client-py/deployments',
#   'created_at': '2017-11-27T00:06:27Z',
#   'updated_at': '2017-11-27T00:06:30Z',
#   'pushed_at': '2017-11-01T05:04:52Z',
#   'git_url': 'git://github.com/Arborian/client-py.git',
#   'ssh_url': 'git@github.com:Arborian/client-py.git',
#   'clone_url': 'https://github.com/Arborian/client-py.git',
#   'svn_url': 'https://github.com/Arborian/client-py',
#   'homepage': 'http://docs.smarthealthit.org',
#   'size': 13647,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 112634642,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMTI2MzQ2NDI=',
#   'name': 'supreload',
#   'full_name': 'Arborian/supreload',
#   'private': False,
#   'owner': {'login': 'Arborian',
#    'id': 24494919,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI0NDk0OTE5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24494919?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Arborian',
#    'html_url': 'https://github.com/Arborian',
#    'followers_url': 'https://api.github.com/users/Arborian/followers',
#    'following_url': 'https://api.github.com/users/Arborian/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Arborian/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Arborian/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Arborian/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Arborian/orgs',
#    'repos_url': 'https://api.github.com/users/Arborian/repos',
#    'events_url': 'https://api.github.com/users/Arborian/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Arborian/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/Arborian/supreload',
#   'description': 'Watchdog-based reloader library',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Arborian/supreload',
#   'forks_url': 'https://api.github.com/repos/Arborian/supreload/forks',
#   'keys_url': 'https://api.github.com/repos/Arborian/supreload/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Arborian/supreload/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Arborian/supreload/teams',
#   'hooks_url': 'https://api.github.com/repos/Arborian/supreload/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Arborian/supreload/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Arborian/supreload/events',
#   'assignees_url': 'https://api.github.com/repos/Arborian/supreload/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Arborian/supreload/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Arborian/supreload/tags',
#   'blobs_url': 'https://api.github.com/repos/Arborian/supreload/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Arborian/supreload/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Arborian/supreload/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Arborian/supreload/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Arborian/supreload/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Arborian/supreload/languages',
#   'stargazers_url': 'https://api.github.com/repos/Arborian/supreload/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Arborian/supreload/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Arborian/supreload/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Arborian/supreload/subscription',
#   'commits_url': 'https://api.github.com/repos/Arborian/supreload/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Arborian/supreload/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Arborian/supreload/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Arborian/supreload/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Arborian/supreload/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Arborian/supreload/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Arborian/supreload/merges',
#   'archive_url': 'https://api.github.com/repos/Arborian/supreload/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Arborian/supreload/downloads',
#   'issues_url': 'https://api.github.com/repos/Arborian/supreload/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Arborian/supreload/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Arborian/supreload/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Arborian/supreload/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Arborian/supreload/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Arborian/supreload/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Arborian/supreload/deployments',
#   'created_at': '2017-11-30T16:33:30Z',
#   'updated_at': '2017-11-30T16:33:30Z',
#   'pushed_at': '2017-11-30T16:33:31Z',
#   'git_url': 'git://github.com/Arborian/supreload.git',
#   'ssh_url': 'git@github.com:Arborian/supreload.git',
#   'clone_url': 'https://github.com/Arborian/supreload.git',
#   'svn_url': 'https://github.com/Arborian/supreload',
#   'homepage': None,
#   'size': 5,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 112743705,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMTI3NDM3MDU=',
#   'name': 'react-big-calendar',
#   'full_name': 'Arborian/react-big-calendar',
#   'private': False,
#   'owner': {'login': 'Arborian',
#    'id': 24494919,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI0NDk0OTE5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24494919?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Arborian',
#    'html_url': 'https://github.com/Arborian',
#    'followers_url': 'https://api.github.com/users/Arborian/followers',
#    'following_url': 'https://api.github.com/users/Arborian/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Arborian/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Arborian/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Arborian/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Arborian/orgs',
#    'repos_url': 'https://api.github.com/users/Arborian/repos',
#    'events_url': 'https://api.github.com/users/Arborian/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Arborian/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/Arborian/react-big-calendar',
#   'description': 'gcal/outlook like calendar component',
#   'fork': True,
#   'url': 'https://api.github.com/repos/Arborian/react-big-calendar',
#   'forks_url': 'https://api.github.com/repos/Arborian/react-big-calendar/forks',
#   'keys_url': 'https://api.github.com/repos/Arborian/react-big-calendar/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Arborian/react-big-calendar/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Arborian/react-big-calendar/teams',
#   'hooks_url': 'https://api.github.com/repos/Arborian/react-big-calendar/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Arborian/react-big-calendar/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Arborian/react-big-calendar/events',
#   'assignees_url': 'https://api.github.com/repos/Arborian/react-big-calendar/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Arborian/react-big-calendar/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Arborian/react-big-calendar/tags',
#   'blobs_url': 'https://api.github.com/repos/Arborian/react-big-calendar/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Arborian/react-big-calendar/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Arborian/react-big-calendar/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Arborian/react-big-calendar/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Arborian/react-big-calendar/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Arborian/react-big-calendar/languages',
#   'stargazers_url': 'https://api.github.com/repos/Arborian/react-big-calendar/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Arborian/react-big-calendar/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Arborian/react-big-calendar/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Arborian/react-big-calendar/subscription',
#   'commits_url': 'https://api.github.com/repos/Arborian/react-big-calendar/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Arborian/react-big-calendar/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Arborian/react-big-calendar/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Arborian/react-big-calendar/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Arborian/react-big-calendar/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Arborian/react-big-calendar/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Arborian/react-big-calendar/merges',
#   'archive_url': 'https://api.github.com/repos/Arborian/react-big-calendar/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Arborian/react-big-calendar/downloads',
#   'issues_url': 'https://api.github.com/repos/Arborian/react-big-calendar/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Arborian/react-big-calendar/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Arborian/react-big-calendar/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Arborian/react-big-calendar/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Arborian/react-big-calendar/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Arborian/react-big-calendar/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Arborian/react-big-calendar/deployments',
#   'created_at': '2017-12-01T13:36:19Z',
#   'updated_at': '2020-02-13T16:03:25Z',
#   'pushed_at': '2017-11-28T17:06:48Z',
#   'git_url': 'git://github.com/Arborian/react-big-calendar.git',
#   'ssh_url': 'git@github.com:Arborian/react-big-calendar.git',
#   'clone_url': 'https://github.com/Arborian/react-big-calendar.git',
#   'svn_url': 'https://github.com/Arborian/react-big-calendar',
#   'homepage': None,
#   'size': 3006,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'JavaScript',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 113341518,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMTMzNDE1MTg=',
#   'name': 'fhirstorm',
#   'full_name': 'Arborian/fhirstorm',
#   'private': False,
#   'owner': {'login': 'Arborian',
#    'id': 24494919,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI0NDk0OTE5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24494919?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Arborian',
#    'html_url': 'https://github.com/Arborian',
#    'followers_url': 'https://api.github.com/users/Arborian/followers',
#    'following_url': 'https://api.github.com/users/Arborian/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Arborian/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Arborian/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Arborian/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Arborian/orgs',
#    'repos_url': 'https://api.github.com/users/Arborian/repos',
#    'events_url': 'https://api.github.com/users/Arborian/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Arborian/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/Arborian/fhirstorm',
#   'description': 'SMART on FHIR for Python',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Arborian/fhirstorm',
#   'forks_url': 'https://api.github.com/repos/Arborian/fhirstorm/forks',
#   'keys_url': 'https://api.github.com/repos/Arborian/fhirstorm/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Arborian/fhirstorm/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Arborian/fhirstorm/teams',
#   'hooks_url': 'https://api.github.com/repos/Arborian/fhirstorm/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Arborian/fhirstorm/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Arborian/fhirstorm/events',
#   'assignees_url': 'https://api.github.com/repos/Arborian/fhirstorm/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Arborian/fhirstorm/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Arborian/fhirstorm/tags',
#   'blobs_url': 'https://api.github.com/repos/Arborian/fhirstorm/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Arborian/fhirstorm/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Arborian/fhirstorm/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Arborian/fhirstorm/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Arborian/fhirstorm/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Arborian/fhirstorm/languages',
#   'stargazers_url': 'https://api.github.com/repos/Arborian/fhirstorm/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Arborian/fhirstorm/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Arborian/fhirstorm/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Arborian/fhirstorm/subscription',
#   'commits_url': 'https://api.github.com/repos/Arborian/fhirstorm/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Arborian/fhirstorm/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Arborian/fhirstorm/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Arborian/fhirstorm/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Arborian/fhirstorm/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Arborian/fhirstorm/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Arborian/fhirstorm/merges',
#   'archive_url': 'https://api.github.com/repos/Arborian/fhirstorm/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Arborian/fhirstorm/downloads',
#   'issues_url': 'https://api.github.com/repos/Arborian/fhirstorm/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Arborian/fhirstorm/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Arborian/fhirstorm/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Arborian/fhirstorm/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Arborian/fhirstorm/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Arborian/fhirstorm/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Arborian/fhirstorm/deployments',
#   'created_at': '2017-12-06T16:36:53Z',
#   'updated_at': '2021-06-13T20:48:56Z',
#   'pushed_at': '2021-06-01T22:07:30Z',
#   'git_url': 'git://github.com/Arborian/fhirstorm.git',
#   'ssh_url': 'git@github.com:Arborian/fhirstorm.git',
#   'clone_url': 'https://github.com/Arborian/fhirstorm.git',
#   'svn_url': 'https://github.com/Arborian/fhirstorm',
#   'homepage': None,
#   'size': 76,
#   'stargazers_count': 7,
#   'watchers_count': 7,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 9,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': ['smart-on-fhir'],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 9,
#   'watchers': 7,
#   'default_branch': 'master',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 116793560,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMTY3OTM1NjA=',
#   'name': 'ansible-role-arborian',
#   'full_name': 'Arborian/ansible-role-arborian',
#   'private': False,
#   'owner': {'login': 'Arborian',
#    'id': 24494919,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI0NDk0OTE5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24494919?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Arborian',
#    'html_url': 'https://github.com/Arborian',
#    'followers_url': 'https://api.github.com/users/Arborian/followers',
#    'following_url': 'https://api.github.com/users/Arborian/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Arborian/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Arborian/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Arborian/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Arborian/orgs',
#    'repos_url': 'https://api.github.com/users/Arborian/repos',
#    'events_url': 'https://api.github.com/users/Arborian/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Arborian/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/Arborian/ansible-role-arborian',
#   'description': 'Sample Ansible Role',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Arborian/ansible-role-arborian',
#   'forks_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/forks',
#   'keys_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/teams',
#   'hooks_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/events',
#   'assignees_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/tags',
#   'blobs_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/languages',
#   'stargazers_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/subscription',
#   'commits_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/merges',
#   'archive_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/downloads',
#   'issues_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Arborian/ansible-role-arborian/deployments',
#   'created_at': '2018-01-09T09:17:00Z',
#   'updated_at': '2018-01-09T09:17:00Z',
#   'pushed_at': '2018-01-09T09:22:38Z',
#   'git_url': 'git://github.com/Arborian/ansible-role-arborian.git',
#   'ssh_url': 'git@github.com:Arborian/ansible-role-arborian.git',
#   'clone_url': 'https://github.com/Arborian/ansible-role-arborian.git',
#   'svn_url': 'https://github.com/Arborian/ansible-role-arborian',
#   'homepage': None,
#   'size': 2,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 122478005,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMjI0NzgwMDU=',
#   'name': 'inventory',
#   'full_name': 'Arborian/inventory',
#   'private': False,
#   'owner': {'login': 'Arborian',
#    'id': 24494919,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI0NDk0OTE5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24494919?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Arborian',
#    'html_url': 'https://github.com/Arborian',
#    'followers_url': 'https://api.github.com/users/Arborian/followers',
#    'following_url': 'https://api.github.com/users/Arborian/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Arborian/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Arborian/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Arborian/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Arborian/orgs',
#    'repos_url': 'https://api.github.com/users/Arborian/repos',
#    'events_url': 'https://api.github.com/users/Arborian/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Arborian/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/Arborian/inventory',
#   'description': 'Perpetual inventory system',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Arborian/inventory',
#   'forks_url': 'https://api.github.com/repos/Arborian/inventory/forks',
#   'keys_url': 'https://api.github.com/repos/Arborian/inventory/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Arborian/inventory/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Arborian/inventory/teams',
#   'hooks_url': 'https://api.github.com/repos/Arborian/inventory/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Arborian/inventory/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Arborian/inventory/events',
#   'assignees_url': 'https://api.github.com/repos/Arborian/inventory/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Arborian/inventory/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Arborian/inventory/tags',
#   'blobs_url': 'https://api.github.com/repos/Arborian/inventory/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Arborian/inventory/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Arborian/inventory/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Arborian/inventory/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Arborian/inventory/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Arborian/inventory/languages',
#   'stargazers_url': 'https://api.github.com/repos/Arborian/inventory/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Arborian/inventory/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Arborian/inventory/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Arborian/inventory/subscription',
#   'commits_url': 'https://api.github.com/repos/Arborian/inventory/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Arborian/inventory/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Arborian/inventory/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Arborian/inventory/issues/comments{/number}',
# ...
#   'owner': {'login': 'Arborian',
#    'id': 24494919,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI0NDk0OTE5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24494919?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Arborian',
#    'html_url': 'https://github.com/Arborian',
#    'followers_url': 'https://api.github.com/users/Arborian/followers',
#    'following_url': 'https://api.github.com/users/Arborian/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Arborian/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Arborian/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Arborian/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Arborian/orgs',
#    'repos_url': 'https://api.github.com/users/Arborian/repos',
#    'events_url': 'https://api.github.com/users/Arborian/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Arborian/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/Arborian/sls',
#   'description': 'Short-lived secrets: an in-memory pastebin',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Arborian/sls',
#   'forks_url': 'https://api.github.com/repos/Arborian/sls/forks',
#   'keys_url': 'https://api.github.com/repos/Arborian/sls/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Arborian/sls/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Arborian/sls/teams',
#   'hooks_url': 'https://api.github.com/repos/Arborian/sls/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Arborian/sls/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Arborian/sls/events',
#   'assignees_url': 'https://api.github.com/repos/Arborian/sls/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Arborian/sls/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Arborian/sls/tags',
#   'blobs_url': 'https://api.github.com/repos/Arborian/sls/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Arborian/sls/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Arborian/sls/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Arborian/sls/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Arborian/sls/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Arborian/sls/languages',
#   'stargazers_url': 'https://api.github.com/repos/Arborian/sls/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Arborian/sls/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Arborian/sls/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Arborian/sls/subscription',
#   'commits_url': 'https://api.github.com/repos/Arborian/sls/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Arborian/sls/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Arborian/sls/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Arborian/sls/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Arborian/sls/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Arborian/sls/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Arborian/sls/merges',
#   'archive_url': 'https://api.github.com/repos/Arborian/sls/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Arborian/sls/downloads',
#   'issues_url': 'https://api.github.com/repos/Arborian/sls/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Arborian/sls/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Arborian/sls/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Arborian/sls/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Arborian/sls/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Arborian/sls/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Arborian/sls/deployments',
#   'created_at': '2021-03-16T23:26:51Z',
#   'updated_at': '2021-03-23T16:39:41Z',
#   'pushed_at': '2021-03-23T16:39:39Z',
#   'git_url': 'git://github.com/Arborian/sls.git',
#   'ssh_url': 'git@github.com:Arborian/sls.git',
#   'clone_url': 'https://github.com/Arborian/sls.git',
#   'svn_url': 'https://github.com/Arborian/sls',
#   'homepage': None,
#   'size': 4,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 390797012,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzOTA3OTcwMTI=',
#   'name': 'swaggertest',
#   'full_name': 'Arborian/swaggertest',
#   'private': False,
#   'owner': {'login': 'Arborian',
#    'id': 24494919,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI0NDk0OTE5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24494919?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Arborian',
#    'html_url': 'https://github.com/Arborian',
#    'followers_url': 'https://api.github.com/users/Arborian/followers',
#    'following_url': 'https://api.github.com/users/Arborian/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Arborian/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Arborian/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Arborian/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Arborian/orgs',
#    'repos_url': 'https://api.github.com/users/Arborian/repos',
#    'events_url': 'https://api.github.com/users/Arborian/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Arborian/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/Arborian/swaggertest',
#   'description': 'Tool for testing swagger specifications',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Arborian/swaggertest',
#   'forks_url': 'https://api.github.com/repos/Arborian/swaggertest/forks',
#   'keys_url': 'https://api.github.com/repos/Arborian/swaggertest/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Arborian/swaggertest/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Arborian/swaggertest/teams',
#   'hooks_url': 'https://api.github.com/repos/Arborian/swaggertest/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Arborian/swaggertest/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Arborian/swaggertest/events',
#   'assignees_url': 'https://api.github.com/repos/Arborian/swaggertest/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Arborian/swaggertest/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Arborian/swaggertest/tags',
#   'blobs_url': 'https://api.github.com/repos/Arborian/swaggertest/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Arborian/swaggertest/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Arborian/swaggertest/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Arborian/swaggertest/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Arborian/swaggertest/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Arborian/swaggertest/languages',
#   'stargazers_url': 'https://api.github.com/repos/Arborian/swaggertest/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Arborian/swaggertest/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Arborian/swaggertest/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Arborian/swaggertest/subscription',
#   'commits_url': 'https://api.github.com/repos/Arborian/swaggertest/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Arborian/swaggertest/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Arborian/swaggertest/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Arborian/swaggertest/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Arborian/swaggertest/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Arborian/swaggertest/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Arborian/swaggertest/merges',
#   'archive_url': 'https://api.github.com/repos/Arborian/swaggertest/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Arborian/swaggertest/downloads',
#   'issues_url': 'https://api.github.com/repos/Arborian/swaggertest/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Arborian/swaggertest/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Arborian/swaggertest/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Arborian/swaggertest/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Arborian/swaggertest/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Arborian/swaggertest/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Arborian/swaggertest/deployments',
#   'created_at': '2021-07-29T17:06:49Z',
#   'updated_at': '2021-07-29T18:28:10Z',
#   'pushed_at': '2021-07-29T18:28:08Z',
#   'git_url': 'git://github.com/Arborian/swaggertest.git',
#   'ssh_url': 'git@github.com:Arborian/swaggertest.git',
#   'clone_url': 'https://github.com/Arborian/swaggertest.git',
#   'svn_url': 'https://github.com/Arborian/swaggertest',
#   'homepage': None,
#   'size': 12,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 414337658,
#   'node_id': 'R_kgDOGLJKeg',
#   'name': 'barin2',
#   'full_name': 'Arborian/barin2',
#   'private': False,
#   'owner': {'login': 'Arborian',
#    'id': 24494919,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI0NDk0OTE5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24494919?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Arborian',
#    'html_url': 'https://github.com/Arborian',
#    'followers_url': 'https://api.github.com/users/Arborian/followers',
#    'following_url': 'https://api.github.com/users/Arborian/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Arborian/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Arborian/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Arborian/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Arborian/orgs',
#    'repos_url': 'https://api.github.com/users/Arborian/repos',
#    'events_url': 'https://api.github.com/users/Arborian/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Arborian/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/Arborian/barin2',
#   'description': 'Barin (2nd Gen)',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Arborian/barin2',
#   'forks_url': 'https://api.github.com/repos/Arborian/barin2/forks',
#   'keys_url': 'https://api.github.com/repos/Arborian/barin2/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Arborian/barin2/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Arborian/barin2/teams',
#   'hooks_url': 'https://api.github.com/repos/Arborian/barin2/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Arborian/barin2/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Arborian/barin2/events',
#   'assignees_url': 'https://api.github.com/repos/Arborian/barin2/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Arborian/barin2/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Arborian/barin2/tags',
#   'blobs_url': 'https://api.github.com/repos/Arborian/barin2/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Arborian/barin2/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Arborian/barin2/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Arborian/barin2/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Arborian/barin2/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Arborian/barin2/languages',
#   'stargazers_url': 'https://api.github.com/repos/Arborian/barin2/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Arborian/barin2/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Arborian/barin2/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Arborian/barin2/subscription',
#   'commits_url': 'https://api.github.com/repos/Arborian/barin2/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Arborian/barin2/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Arborian/barin2/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Arborian/barin2/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Arborian/barin2/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Arborian/barin2/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Arborian/barin2/merges',
#   'archive_url': 'https://api.github.com/repos/Arborian/barin2/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Arborian/barin2/downloads',
#   'issues_url': 'https://api.github.com/repos/Arborian/barin2/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Arborian/barin2/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Arborian/barin2/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Arborian/barin2/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Arborian/barin2/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Arborian/barin2/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Arborian/barin2/deployments',
#   'created_at': '2021-10-06T19:02:45Z',
#   'updated_at': '2021-10-08T12:25:01Z',
#   'pushed_at': '2021-10-08T12:24:58Z',
#   'git_url': 'git://github.com/Arborian/barin2.git',
#   'ssh_url': 'git@github.com:Arborian/barin2.git',
#   'clone_url': 'https://github.com/Arborian/barin2.git',
#   'svn_url': 'https://github.com/Arborian/barin2',
#   'homepage': None,
#   'size': 19,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}}]

# %%
for repo in repos:
    if repo['name'] == 'recommender':
        break

# %%
repo['name']
# Out:
# 'recommender'

# %%
repo['commits_url']
# Out:
# 'https://api.github.com/repos/Arborian/recommender/commits{/sha}'

# %%
url = uritemplate.expand(
    repo['commits_url'],
    sha='3a0b9b6617dbad6ed79e01d04312840232943967'
)
r = session.get(url)

# %%
r.json()
# Out:
# {'sha': '3a0b9b6617dbad6ed79e01d04312840232943967',
#  'node_id': 'MDY6Q29tbWl0MTcxMzYyNTQzOjNhMGI5YjY2MTdkYmFkNmVkNzllMDFkMDQzMTI4NDAyMzI5NDM5Njc=',
#  'commit': {'author': {'name': 'Rick Copeland',
#    'email': 'rick@arborian.com',
#    'date': '2019-02-19T00:28:00Z'},
#   'committer': {'name': 'Rick Copeland',
#    'email': 'rick@arborian.com',
#    'date': '2019-02-19T00:28:00Z'},
#   'message': 'remove print statement',
#   'tree': {'sha': 'a6607f3243618656931442d7d110c68dcf0a245f',
#    'url': 'https://api.github.com/repos/Arborian/recommender/git/trees/a6607f3243618656931442d7d110c68dcf0a245f'},
#   'url': 'https://api.github.com/repos/Arborian/recommender/git/commits/3a0b9b6617dbad6ed79e01d04312840232943967',
#   'comment_count': 0,
#   'verification': {'verified': False,
#    'reason': 'unsigned',
#    'signature': None,
#    'payload': None}},
#  'url': 'https://api.github.com/repos/Arborian/recommender/commits/3a0b9b6617dbad6ed79e01d04312840232943967',
#  'html_url': 'https://github.com/Arborian/recommender/commit/3a0b9b6617dbad6ed79e01d04312840232943967',
#  'comments_url': 'https://api.github.com/repos/Arborian/recommender/commits/3a0b9b6617dbad6ed79e01d04312840232943967/comments',
#  'author': {'login': 'rick446',
#   'id': 196783,
#   'node_id': 'MDQ6VXNlcjE5Njc4Mw==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/196783?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/rick446',
#   'html_url': 'https://github.com/rick446',
#   'followers_url': 'https://api.github.com/users/rick446/followers',
#   'following_url': 'https://api.github.com/users/rick446/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/rick446/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/rick446/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/rick446/subscriptions',
#   'organizations_url': 'https://api.github.com/users/rick446/orgs',
#   'repos_url': 'https://api.github.com/users/rick446/repos',
#   'events_url': 'https://api.github.com/users/rick446/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/rick446/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'committer': {'login': 'rick446',
#   'id': 196783,
#   'node_id': 'MDQ6VXNlcjE5Njc4Mw==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/196783?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/rick446',
#   'html_url': 'https://github.com/rick446',
#   'followers_url': 'https://api.github.com/users/rick446/followers',
#   'following_url': 'https://api.github.com/users/rick446/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/rick446/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/rick446/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/rick446/subscriptions',
#   'organizations_url': 'https://api.github.com/users/rick446/orgs',
#   'repos_url': 'https://api.github.com/users/rick446/repos',
#   'events_url': 'https://api.github.com/users/rick446/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/rick446/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'parents': [{'sha': '15f51b9603e1b48d41a0e59213f1d14fe370cb6f',
#    'url': 'https://api.github.com/repos/Arborian/recommender/commits/15f51b9603e1b48d41a0e59213f1d14fe370cb6f',
#    'html_url': 'https://github.com/Arborian/recommender/commit/15f51b9603e1b48d41a0e59213f1d14fe370cb6f'}],
#  'stats': {'total': 1, 'additions': 0, 'deletions': 1},
#  'files': [{'sha': '075d27a96ede7b0a361c4984674df56e78f3dee6',
#    'filename': 'recommender/workflow_dev/workflow_test.py',
#    'status': 'modified',
#    'additions': 0,
#    'deletions': 1,
#    'changes': 1,
#    'blob_url': 'https://github.com/Arborian/recommender/blob/3a0b9b6617dbad6ed79e01d04312840232943967/recommender/workflow_dev/workflow_test.py',
#    'raw_url': 'https://github.com/Arborian/recommender/raw/3a0b9b6617dbad6ed79e01d04312840232943967/recommender/workflow_dev/workflow_test.py',
#    'contents_url': 'https://api.github.com/repos/Arborian/recommender/contents/recommender/workflow_dev/workflow_test.py?ref=3a0b9b6617dbad6ed79e01d04312840232943967',
#    'patch': "@@ -35,4 +35,3 @@ def setUp(self):\n     def test_stage_1(self):\n         stage = Stage1(self.config_stage1)\n         result = stage.execute()\n-        print(result['scores'])\n\\ No newline at end of file"}]}

# %%
_10['commit']['author']['email']
# Out:
# 'rick@arborian.com'

# %%
print(r.json()['files'][0]['patch'])
# Out:
# @@ -35,4 +35,3 @@ def setUp(self):
#      def test_stage_1(self):
#          stage = Stage1(self.config_stage1)
#          result = stage.execute()
# -        print(result['scores'])
# \ No newline at end of file

# %%
# !pip install glom
# Out:
# Looking in links: /home/rick446/src/wheelhouse
# Requirement already satisfied: glom in /home/rick446/.virtualenvs/classes/lib/python3.8/site-packages (20.8.0)
# Requirement already satisfied: attrs in /home/rick446/.virtualenvs/classes/lib/python3.8/site-packages (from glom) (20.2.0)
# Requirement already satisfied: boltons>=19.3.0 in /home/rick446/.virtualenvs/classes/lib/python3.8/site-packages (from glom) (20.2.1)
# Requirement already satisfied: face>=20.1.0 in /home/rick446/.virtualenvs/classes/lib/python3.8/site-packages (from glom) (20.1.1)
# WARNING: You are using pip version 20.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/rick446/.virtualenvs/classes/bin/python -m pip install --upgrade pip' command.

# %%
import glom

# %%
print(glom.glom(r.json(), 'files.0.patch'))
# Out:
# @@ -35,4 +35,3 @@ def setUp(self):
#      def test_stage_1(self):
#          stage = Stage1(self.config_stage1)
#          result = stage.execute()
# -        print(result['scores'])
# \ No newline at end of file

# %%
glom.glom(r.json(), 'commit.author.email')
# Out:
# 'rick@arborian.com'
