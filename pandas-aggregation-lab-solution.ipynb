# %% [markdown]
# Read in the `./data/merged-sales.csv` from the previous exercise:

# %%
import pandas as pd

merged_sales = pd.read_csv('./data/merged-sales.csv')
merged_sales.head()
# Out:
#    order_num  line_num        date       sku  qty category    price   revenue
# 0          0         0  2011-01-01   sku4333    6  Showers  1563.90   9383.40
# 1        641         3  2012-10-10   sku4333    8  Showers  1563.90  12511.20
# 2          0         1  2011-01-01  sku76536    7  Faucets  3121.99  21853.93
# 3          1         0  2011-01-02  sku75108    3     Misc   819.55   2458.65
# 4          1         1  2011-01-02  sku78838    9  Showers  2531.54  22783.86

# %%
def make_orderid(row):
    return f'{row.order_num}_{row.line_num}'

merged_sales['orderid'] = merged_sales.apply(make_orderid, axis=1)
merged_sales = merged_sales.set_index('orderid')
merged_sales.head()
# Out:
#          order_num  line_num        date       sku  qty category    price  \
# orderid
# 0_0              0         0  2011-01-01   sku4333    6  Showers  1563.90
# 641_3          641         3  2012-10-10   sku4333    8  Showers  1563.90
# 0_1              0         1  2011-01-01  sku76536    7  Faucets  3121.99
# 1_0              1         0  2011-01-02  sku75108    3     Misc   819.55
# 1_1              1         1  2011-01-02  sku78838    9  Showers  2531.54
#
#           revenue
# orderid
# 0_0       9383.40
# 641_3    12511.20
# 0_1      21853.93
# 1_0       2458.65
# 1_1      22783.86

# %%
merged_sales.set_index(['order_num', 'line_num']).head()
# Out:
#                           date       sku  qty category    price   revenue
# order_num line_num
# 0         0         2011-01-01   sku4333    6  Showers  1563.90   9383.40
# 641       3         2012-10-10   sku4333    8  Showers  1563.90  12511.20
# 0         1         2011-01-01  sku76536    7  Faucets  3121.99  21853.93
# 1         0         2011-01-02  sku75108    3     Misc   819.55   2458.65
#           1         2011-01-02  sku78838    9  Showers  2531.54  22783.86

# %% [markdown]
# Generate a dataframe showing the total quantity sold and mean price per category

# %%
merged_sales.groupby('category').agg({
    'qty': ['sum'], 
    'price': ['mean']
})
# Out:
#            qty        price
#            sum         mean
# category
# Faucets   2888  2431.517419
# Misc      3238  2501.622278
# Showers   3057  2469.608597
# Toilets   2857  2450.498562

# %%
g = merged_sales.groupby('category')

# %%
pd.concat([
    g.qty.sum().rename('qty_sum'),
    g.price.mean().rename('price_mean')
], axis=1)
# Out:
#           qty_sum   price_mean
# category
# Faucets      2888  2431.517419
# Misc         3238  2501.622278
# Showers      3057  2469.608597
# Toilets      2857  2450.498562

# %% [markdown]
# Add a column `order_share` that shows what percentage of the order total each line item is (in revenue)

# %%
g = merged_sales.groupby('order_num')
g.revenue.agg('sum').head(20)
# Out:
# order_num
# 0     31237.33
# 1     32879.28
# 2     32284.50
# 3     50845.71
# 4     17308.97
# 5     13462.40
# 6     29113.67
# 7     35934.42
# 8     25182.55
# 9     11458.38
# 10     4338.16
# 11     2891.96
# 12     3644.78
# 13    57723.10
# 14    29416.54
# 15    23799.06
# 16    48692.40
# 17     8353.31
# 18    70804.24
# 19    55060.08
# Name: revenue, dtype: float64

# %%
merged_sales.revenue.head()
# Out:
# orderid
# 0_0       9383.40
# 641_3    12511.20
# 0_1      21853.93
# 1_0       2458.65
# 1_1      22783.86
# Name: revenue, dtype: float64

# %%
order_sales = g.revenue.transform('sum')
order_sales.head(20)
# Out:
# orderid
# 0_0      31237.33
# 641_3    61857.12
# 0_1      31237.33
# 1_0      32879.28
# 1_1      32879.28
# 1_2      32879.28
# 2_0      32284.50
# 2_1      32284.50
# 2_2      32284.50
# 3_0      50845.71
# 3_1      50845.71
# 3_2      50845.71
# 4_0      17308.97
# 4_1      17308.97
# 4_2      17308.97
# 4_3      17308.97
# 5_0      13462.40
# 6_0      29113.67
# 6_1      29113.67
# 6_2      29113.67
# Name: revenue, dtype: float64

# %%
merged_sales['order_share'] = merged_sales['revenue'] / order_sales
merged_sales.head()
# Out:
#          order_num  line_num        date       sku  qty category    price  \
# orderid
# 0_0              0         0  2011-01-01   sku4333    6  Showers  1563.90
# 641_3          641         3  2012-10-10   sku4333    8  Showers  1563.90
# 0_1              0         1  2011-01-01  sku76536    7  Faucets  3121.99
# 1_0              1         0  2011-01-02  sku75108    3     Misc   819.55
# 1_1              1         1  2011-01-02  sku78838    9  Showers  2531.54
#
#           revenue  order_share
# orderid
# 0_0       9383.40     0.300391
# 641_3    12511.20     0.202260
# 0_1      21853.93     0.699609
# 1_0       2458.65     0.074778
# 1_1      22783.86     0.692955

# %% [markdown]
# Show rows for orders 0-5, in sorted order.

# %%
merged_sales[merged_sales.order_num < 6].sort_values(['order_num', 'line_num'])
# Out:
#          order_num  line_num        date       sku  qty category    price  \
# orderid
# 0_0              0         0  2011-01-01   sku4333    6  Showers  1563.90
# 0_1              0         1  2011-01-01  sku76536    7  Faucets  3121.99
# 1_0              1         0  2011-01-02  sku75108    3     Misc   819.55
# 1_1              1         1  2011-01-02  sku78838    9  Showers  2531.54
# 1_2              1         2  2011-01-02  sku77480    9  Faucets   848.53
# 2_0              2         0  2011-01-05  sku45155    3     Misc  2682.97
# 2_1              2         1  2011-01-05  sku67327    9     Misc  1593.51
# 2_2              2         2  2011-01-05  sku27757    8     Misc  1236.75
# 3_0              3         0  2011-01-06  sku82064    4     Misc   771.72
# 3_1              3         1  2011-01-06  sku15816    3  Showers  4399.92
# 3_2              3         2  2011-01-06  sku67884    7  Showers  4937.01
# 4_0              4         0  2011-01-08  sku50623    9  Faucets   453.42
# 4_1              4         1  2011-01-08  sku38198    7     Misc  1631.88
# 4_2              4         2  2011-01-08  sku97248    2  Toilets   298.75
# 4_3              4         3  2011-01-08  sku96436    1  Showers  1207.53
# 5_0              5         0  2011-01-09  sku27629    5  Toilets  2692.48
#
#           revenue  order_share
# orderid
# 0_0       9383.40     0.300391
# 0_1      21853.93     0.699609
# 1_0       2458.65     0.074778
# 1_1      22783.86     0.692955
# 1_2       7636.77     0.232267
# 2_0       8048.91     0.249312
# 2_1      14341.59     0.444225
# 2_2       9894.00     0.306463
# 3_0       3086.88     0.060711
# 3_1      13199.76     0.259604
# 3_2      34559.07     0.679685
# 4_0       4080.78     0.235761
# 4_1      11423.16     0.659956
# 4_2        597.50     0.034520
# 4_3       1207.53     0.069763
# 5_0      13462.40     1.000000

# %% [markdown]
# Without transform...

# %%
df = pd.read_csv('./data/merged-sales.csv')
df.head()
# Out:
#    order_num  line_num        date       sku  qty category    price   revenue
# 0          0         0  2011-01-01   sku4333    6  Showers  1563.90   9383.40
# 1        641         3  2012-10-10   sku4333    8  Showers  1563.90  12511.20
# 2          0         1  2011-01-01  sku76536    7  Faucets  3121.99  21853.93
# 3          1         0  2011-01-02  sku75108    3     Misc   819.55   2458.65
# 4          1         1  2011-01-02  sku78838    9  Showers  2531.54  22783.86

# %%
order_total = df.groupby('order_num').revenue.sum().rename('order_total')
order_total
# Out:
# order_num
# 0      31237.33
# 1      32879.28
# 2      32284.50
# 3      50845.71
# 4      17308.97
#          ...
# 986    92766.81
# 987    62268.66
# 988    14172.84
# 989    80476.62
# 990    32148.18
# Name: order_total, Length: 991, dtype: float64

# %%
df = pd.merge(df, order_total, left_on='order_num', right_index=True)
df.head()
# Out:
#       order_num  line_num        date       sku  qty category    price  \
# 0             0         0  2011-01-01   sku4333    6  Showers  1563.90
# 2             0         1  2011-01-01  sku76536    7  Faucets  3121.99
# 1           641         3  2012-10-10   sku4333    8  Showers  1563.90
# 1613        641         0  2012-10-10  sku93325    9  Showers  1650.08
# 1614        641         1  2012-10-10  sku69868    2  Showers  2625.48
#
#        revenue  order_total
# 0      9383.40     31237.33
# 2     21853.93     31237.33
# 1     12511.20     61857.12
# 1613  14850.72     61857.12
# 1614   5250.96     61857.12

# %%
df['order_share'] = df['revenue'] / df['order_total']

# %%
df.head()
# Out:
#       order_num  line_num        date       sku  qty category    price  \
# 0             0         0  2011-01-01   sku4333    6  Showers  1563.90
# 2             0         1  2011-01-01  sku76536    7  Faucets  3121.99
# 1           641         3  2012-10-10   sku4333    8  Showers  1563.90
# 1613        641         0  2012-10-10  sku93325    9  Showers  1650.08
# 1614        641         1  2012-10-10  sku69868    2  Showers  2625.48
#
#        revenue  order_total  order_share
# 0      9383.40     31237.33     0.300391
# 2     21853.93     31237.33     0.699609
# 1     12511.20     61857.12     0.202260
# 1613  14850.72     61857.12     0.240081
# 1614   5250.96     61857.12     0.084889
